# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Ahmad-1263/code-switching-codesaviours-si26-Muhammad-Ahmad/blob/main/SI26_Week6_MuhammadAhmad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code Switching NLP | Code Saviours SI-26 | Muhammad Ahmad
# ## Week 6 — Roman Urdu / English Code-Switching Dataset Collection

# %% [markdown]
# ## Cell 1 — Create the labelled dataset
# 155 hand-curated Roman Urdu–English code-switched sentences, labelled word by word as URD / ENG / MIX, exported to dataset.csv.

# %%
import pandas as pd
import random

random.seed(42)

# ---------------------------------------------------------------
# Hand-built pool of realistic Roman-Urdu / English code-switched
# sentences with word-level labels.
# URD = Roman Urdu word, ENG = English word,
# MIX = assimilated loanword / hybrid form commonly used by both
#       language communities (e.g. "mobile", "internet", "ok")
# ---------------------------------------------------------------

data = [
    {"sentence": "Aaj ka din bohot busy tha", "words": ["Aaj","ka","din","bohot","busy","tha"], "labels": ["URD","URD","URD","URD","ENG","URD"]},
    {"sentence": "Yaar seriously I can not even right now", "words": ["Yaar","seriously","I","can","not","even","right","now"], "labels": ["URD","ENG","ENG","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Bhai kal mera presentation hai still not prepared at all", "words": ["Bhai","kal","mera","presentation","hai","still","not","prepared","at","all"], "labels": ["URD","URD","URD","ENG","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Khana kha liya I was literally waiting for you", "words": ["Khana","kha","liya","I","was","literally","waiting","for","you"], "labels": ["URD","URD","URD","ENG","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Mujhe bilkul samajh nahi aa raha what to do next", "words": ["Mujhe","bilkul","samajh","nahi","aa","raha","what","to","do","next"], "labels": ["URD","URD","URD","URD","URD","URD","ENG","ENG","ENG","ENG"]},
    {"sentence": "Yeh assignment tou bohot mushkil lag raha hai honestly", "words": ["Yeh","assignment","tou","bohot","mushkil","lag","raha","hai","honestly"], "labels": ["URD","ENG","URD","URD","URD","URD","URD","URD","ENG"]},
    {"sentence": "I swear mera sar dard kar raha hai abhi", "words": ["I","swear","mera","sar","dard","kar","raha","hai","abhi"], "labels": ["ENG","ENG","URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Chalo let's just finish this project aaj hi", "words": ["Chalo","let's","just","finish","this","project","aaj","hi"], "labels": ["URD","ENG","ENG","ENG","ENG","ENG","URD","URD"]},
    {"sentence": "Yaar itna kaam hai but I have zero motivation", "words": ["Yaar","itna","kaam","hai","but","I","have","zero","motivation"], "labels": ["URD","URD","URD","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Kal exam tha and I totally forgot about it", "words": ["Kal","exam","tha","and","I","totally","forgot","about","it"], "labels": ["URD","ENG","URD","ENG","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Mera phone hang ho gaya again", "words": ["Mera","phone","hang","ho","gaya","again"], "labels": ["URD","MIX","ENG","URD","URD","ENG"]},
    {"sentence": "Bas thori der mein aa jaunga wait kar lo", "words": ["Bas","thori","der","mein","aa","jaunga","wait","kar","lo"], "labels": ["URD","URD","URD","URD","URD","URD","ENG","URD","URD"]},
    {"sentence": "Honestly mujhe kuch samajh nahi aa raha", "words": ["Honestly","mujhe","kuch","samajh","nahi","aa","raha"], "labels": ["ENG","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Weekend pe hum log beach jaa rahe hain", "words": ["Weekend","pe","hum","log","beach","jaa","rahe","hain"], "labels": ["ENG","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Mujhe laga tha ke tum time pe aao gay", "words": ["Mujhe","laga","tha","ke","tum","time","pe","aao","gay"], "labels": ["URD","URD","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Yaar please thora sabar kar lo abhi busy hoon", "words": ["Yaar","please","thora","sabar","kar","lo","abhi","busy","hoon"], "labels": ["URD","ENG","URD","URD","URD","URD","URD","ENG","URD"]},
    {"sentence": "I don't know yaar kya karna hai ab", "words": ["I","don't","know","yaar","kya","karna","hai","ab"], "labels": ["ENG","ENG","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Subha se meeting attend kar rahi hoon nonstop", "words": ["Subha","se","meeting","attend","kar","rahi","hoon","nonstop"], "labels": ["URD","URD","ENG","ENG","URD","URD","URD","ENG"]},
    {"sentence": "Mujhe bharosa nahi tha ke ye deal ho jayegi", "words": ["Mujhe","bharosa","nahi","tha","ke","ye","deal","ho","jayegi"], "labels": ["URD","URD","URD","URD","URD","URD","ENG","URD","URD"]},
    {"sentence": "Chill karo yaar itna stress nahi lena chahiye", "words": ["Chill","karo","yaar","itna","stress","nahi","lena","chahiye"], "labels": ["ENG","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Traffic itni zyada thi that I got super late", "words": ["Traffic","itni","zyada","thi","that","I","got","super","late"], "labels": ["ENG","URD","URD","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Ab tou bas ek hi option bacha hai", "words": ["Ab","tou","bas","ek","hi","option","bacha","hai"], "labels": ["URD","URD","URD","URD","URD","ENG","URD","URD"]},
    {"sentence": "Mera mood bilkul off hai aaj kal", "words": ["Mera","mood","bilkul","off","hai","aaj","kal"], "labels": ["URD","ENG","URD","ENG","URD","URD","URD"]},
    {"sentence": "Kabhi kabhi lagta hai ke life is just unfair", "words": ["Kabhi","kabhi","lagta","hai","ke","life","is","just","unfair"], "labels": ["URD","URD","URD","URD","URD","ENG","ENG","ENG","ENG"]},
    {"sentence": "Aap please thora patience rakhein its almost done", "words": ["Aap","please","thora","patience","rakhein","its","almost","done"], "labels": ["URD","ENG","URD","ENG","URD","ENG","ENG","ENG"]},
    {"sentence": "Mujhe office se late reply mila tha yesterday", "words": ["Mujhe","office","se","late","reply","mila","tha","yesterday"], "labels": ["URD","ENG","URD","ENG","ENG","URD","URD","ENG"]},
    {"sentence": "Yeh internet ka connection bohot slow hai aaj", "words": ["Yeh","internet","ka","connection","bohot","slow","hai","aaj"], "labels": ["URD","MIX","URD","ENG","URD","ENG","URD","URD"]},
    {"sentence": "I really need thora break warna pagal ho jaunga", "words": ["I","really","need","thora","break","warna","pagal","ho","jaunga"], "labels": ["ENG","ENG","ENG","URD","ENG","URD","URD","URD","URD"]},
    {"sentence": "Kal raat neend hi nahi aayi thi properly", "words": ["Kal","raat","neend","hi","nahi","aayi","thi","properly"], "labels": ["URD","URD","URD","URD","URD","URD","URD","ENG"]},
    {"sentence": "Excited hoon for this weekend trip yaar", "words": ["Excited","hoon","for","this","weekend","trip","yaar"], "labels": ["ENG","URD","ENG","ENG","ENG","ENG","URD"]},
    {"sentence": "Mujhe abhi bhi believe nahi ho raha ke ye sach hai", "words": ["Mujhe","abhi","bhi","believe","nahi","ho","raha","ke","ye","sach","hai"], "labels": ["URD","URD","URD","ENG","URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Ap ka message dekha but I forgot to reply", "words": ["Ap","ka","message","dekha","but","I","forgot","to","reply"], "labels": ["URD","URD","ENG","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Zara wait karo main bas coming hoon", "words": ["Zara","wait","karo","main","bas","coming","hoon"], "labels": ["URD","ENG","URD","URD","URD","ENG","URD"]},
    {"sentence": "Itni garmi hai I can barely breathe outside", "words": ["Itni","garmi","hai","I","can","barely","breathe","outside"], "labels": ["URD","URD","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Mera data khatam ho gaya call nahi kar sakta", "words": ["Mera","data","khatam","ho","gaya","call","nahi","kar","sakta"], "labels": ["URD","MIX","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Yaar exam ka result aa gaya I am so relieved", "words": ["Yaar","exam","ka","result","aa","gaya","I","am","so","relieved"], "labels": ["URD","ENG","URD","ENG","URD","URD","ENG","ENG","ENG","ENG"]},
    {"sentence": "Abhi mood nahi hai for anything honestly", "words": ["Abhi","mood","nahi","hai","for","anything","honestly"], "labels": ["URD","ENG","URD","URD","ENG","ENG","ENG"]},
    {"sentence": "Kitni dair se wait kar rahi hoon tumhara", "words": ["Kitni","dair","se","wait","kar","rahi","hoon","tumhara"], "labels": ["URD","URD","URD","ENG","URD","URD","URD","URD"]},
    {"sentence": "Bas thora sa focus karna hai final week hai ye", "words": ["Bas","thora","sa","focus","karna","hai","final","week","hai","ye"], "labels": ["URD","URD","URD","ENG","URD","URD","ENG","ENG","URD","URD"]},
    {"sentence": "Mujhe lagta hai I should just sleep early tonight", "words": ["Mujhe","lagta","hai","I","should","just","sleep","early","tonight"], "labels": ["URD","URD","URD","ENG","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Kaam se break lene ka time hi nahi milta", "words": ["Kaam","se","break","lene","ka","time","hi","nahi","milta"], "labels": ["URD","URD","ENG","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "I think humein plan change karna chahiye ab", "words": ["I","think","humein","plan","change","karna","chahiye","ab"], "labels": ["ENG","ENG","URD","ENG","ENG","URD","URD","URD"]},
    {"sentence": "Sab kuch theek ho jayega don't worry so much", "words": ["Sab","kuch","theek","ho","jayega","don't","worry","so","much"], "labels": ["URD","URD","URD","URD","URD","ENG","ENG","ENG","ENG"]},
    {"sentence": "Mera laptop charge nahi ho raha kal se", "words": ["Mera","laptop","charge","nahi","ho","raha","kal","se"], "labels": ["URD","ENG","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Are you free tonight muje kuch discuss karna tha", "words": ["Are","you","free","tonight","muje","kuch","discuss","karna","tha"], "labels": ["ENG","ENG","ENG","ENG","URD","URD","ENG","URD","URD"]},
    {"sentence": "Yaar bohot mushkil se ye deadline meet ki hai", "words": ["Yaar","bohot","mushkil","se","ye","deadline","meet","ki","hai"], "labels": ["URD","URD","URD","URD","URD","ENG","ENG","URD","URD"]},
    {"sentence": "Mummy ne kaha ke dinner ready hai jaldi aao", "words": ["Mummy","ne","kaha","ke","dinner","ready","hai","jaldi","aao"], "labels": ["URD","URD","URD","URD","ENG","ENG","URD","URD","URD"]},
    {"sentence": "This weather itna suhana hai I want to go out", "words": ["This","weather","itna","suhana","hai","I","want","to","go","out"], "labels": ["ENG","ENG","URD","URD","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Kal se gym start kar raha hoon seriously this time", "words": ["Kal","se","gym","start","kar","raha","hoon","seriously","this","time"], "labels": ["URD","URD","ENG","ENG","URD","URD","URD","ENG","ENG","ENG"]},
    {"sentence": "Mera mood bohot off hai kisi se baat nahi karni", "words": ["Mera","mood","bohot","off","hai","kisi","se","baat","nahi","karni"], "labels": ["URD","ENG","URD","ENG","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Itna sara kaam hai I don't even know where to start", "words": ["Itna","sara","kaam","hai","I","don't","even","know","where","to","start"], "labels": ["URD","URD","URD","URD","ENG","ENG","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Chalo movie dekhne chalte hain aaj shaam ko", "words": ["Chalo","movie","dekhne","chalte","hain","aaj","shaam","ko"], "labels": ["URD","ENG","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Mujhe abhi thora sa headache ho raha hai", "words": ["Mujhe","abhi","thora","sa","headache","ho","raha","hai"], "labels": ["URD","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "I promise kal se sab kuch on time karunga", "words": ["I","promise","kal","se","sab","kuch","on","time","karunga"], "labels": ["ENG","ENG","URD","URD","URD","URD","ENG","ENG","URD"]},
    {"sentence": "Yaar bill split kar lete hain equally", "words": ["Yaar","bill","split","kar","lete","hain","equally"], "labels": ["URD","ENG","ENG","URD","URD","URD","ENG"]},
    {"sentence": "Uska attitude bilkul change ho gaya hai recently", "words": ["Uska","attitude","bilkul","change","ho","gaya","hai","recently"], "labels": ["URD","ENG","URD","ENG","URD","URD","URD","ENG"]},
    {"sentence": "Kal ka plan cancel ho gaya kuch kaam aa gaya", "words": ["Kal","ka","plan","cancel","ho","gaya","kuch","kaam","aa","gaya"], "labels": ["URD","URD","ENG","ENG","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Honestly speaking mujhe koi idea nahi hai", "words": ["Honestly","speaking","mujhe","koi","idea","nahi","hai"], "labels": ["ENG","ENG","URD","URD","ENG","URD","URD"]},
    {"sentence": "Bhai mera internship confirm ho gaya finally", "words": ["Bhai","mera","internship","confirm","ho","gaya","finally"], "labels": ["URD","URD","ENG","ENG","URD","URD","ENG"]},
    {"sentence": "Aajkal sab kuch online ho gaya hai even groceries", "words": ["Aajkal","sab","kuch","online","ho","gaya","hai","even","groceries"], "labels": ["URD","URD","URD","ENG","URD","URD","URD","ENG","ENG"]},
    {"sentence": "I need to submit ye form kal tak", "words": ["I","need","to","submit","ye","form","kal","tak"], "labels": ["ENG","ENG","ENG","ENG","URD","ENG","URD","URD"]},
    {"sentence": "Ammi keh rahi thi ke early aa jao ghar", "words": ["Ammi","keh","rahi","thi","ke","early","aa","jao","ghar"], "labels": ["URD","URD","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Bus mein bohot rush tha today morning", "words": ["Bus","mein","bohot","rush","tha","today","morning"], "labels": ["ENG","URD","URD","ENG","URD","ENG","ENG"]},
    {"sentence": "Kabhi socha nahi tha ke aisa bhi ho sakta hai", "words": ["Kabhi","socha","nahi","tha","ke","aisa","bhi","ho","sakta","hai"], "labels": ["URD","URD","URD","URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Please thora jaldi karo we are getting late", "words": ["Please","thora","jaldi","karo","we","are","getting","late"], "labels": ["ENG","URD","URD","URD","ENG","ENG","ENG","ENG"]},
    {"sentence": "Mujhe wo movie bilkul boring lagi honestly", "words": ["Mujhe","wo","movie","bilkul","boring","lagi","honestly"], "labels": ["URD","URD","ENG","URD","ENG","URD","ENG"]},
    {"sentence": "Sara din phone pe scroll karti rahi", "words": ["Sara","din","phone","pe","scroll","karti","rahi"], "labels": ["URD","URD","MIX","URD","ENG","URD","URD"]},
    {"sentence": "Aaj weather bohot achi hai lets go for a walk", "words": ["Aaj","weather","bohot","achi","hai","lets","go","for","a","walk"], "labels": ["URD","ENG","URD","URD","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Mera schedule bohot tight hai is week", "words": ["Mera","schedule","bohot","tight","hai","is","week"], "labels": ["URD","ENG","URD","ENG","URD","ENG","ENG"]},
    {"sentence": "Yaar kal ka paper bohot tough tha yr", "words": ["Yaar","kal","ka","paper","bohot","tough","tha","yr"], "labels": ["URD","URD","URD","ENG","URD","ENG","URD","MIX"]},
    {"sentence": "Chalein market chalte hain kuch shopping bhi ho jaye", "words": ["Chalein","market","chalte","hain","kuch","shopping","bhi","ho","jaye"], "labels": ["URD","ENG","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "I appreciate it yaar tumne meri madad ki", "words": ["I","appreciate","it","yaar","tumne","meri","madad","ki"], "labels": ["ENG","ENG","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Bohot dinon se socha tha ke ye course start karun", "words": ["Bohot","dinon","se","socha","tha","ke","ye","course","start","karun"], "labels": ["URD","URD","URD","URD","URD","URD","URD","ENG","ENG","URD"]},
    {"sentence": "Mujhe office jaldi nikalna hai traffic ki wajah se", "words": ["Mujhe","office","jaldi","nikalna","hai","traffic","ki","wajah","se"], "labels": ["URD","ENG","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Kal ke liye kuch prepare kar lo warna dikkat hogi", "words": ["Kal","ke","liye","kuch","prepare","kar","lo","warna","dikkat","hogi"], "labels": ["URD","URD","URD","URD","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Ye new phone ka camera kaafi acha hai actually", "words": ["Ye","new","phone","ka","camera","kaafi","acha","hai","actually"], "labels": ["URD","ENG","MIX","URD","ENG","URD","URD","URD","ENG"]},
    {"sentence": "Subha jaldi utha tha but phir bhi late ho gaya", "words": ["Subha","jaldi","utha","tha","but","phir","bhi","late","ho","gaya"], "labels": ["URD","URD","URD","URD","ENG","URD","URD","ENG","URD","URD"]},
    {"sentence": "I really appreciate your help yaar bohot shukriya", "words": ["I","really","appreciate","your","help","yaar","bohot","shukriya"], "labels": ["ENG","ENG","ENG","ENG","ENG","URD","URD","URD"]},
    {"sentence": "Bohot arsay baad aaj achi neend aayi", "words": ["Bohot","arsay","baad","aaj","achi","neend","aayi"], "labels": ["URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Kaam khatam kar ke movie dekhte hain tonight", "words": ["Kaam","khatam","kar","ke","movie","dekhte","hain","tonight"], "labels": ["URD","URD","URD","URD","ENG","URD","URD","ENG"]},
    {"sentence": "Mujhe abhi bhi trust nahi ho raha ke hum graduate ho gaye", "words": ["Mujhe","abhi","bhi","trust","nahi","ho","raha","ke","hum","graduate","ho","gaye"], "labels": ["URD","URD","URD","ENG","URD","URD","URD","URD","URD","ENG","URD","URD"]},
    {"sentence": "Weekend pe koi plan hai kya tumhara", "words": ["Weekend","pe","koi","plan","hai","kya","tumhara"], "labels": ["ENG","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Bhai mujhe abhi thora space chahiye please", "words": ["Bhai","mujhe","abhi","thora","space","chahiye","please"], "labels": ["URD","URD","URD","URD","ENG","URD","ENG"]},
    {"sentence": "Kal se diet start kar raha hoon for real this time", "words": ["Kal","se","diet","start","kar","raha","hoon","for","real","this","time"], "labels": ["URD","URD","ENG","ENG","URD","URD","URD","ENG","ENG","ENG","ENG"]},
    {"sentence": "Aunty ne pucha tha ke shaadi kab kar rahe ho", "words": ["Aunty","ne","pucha","tha","ke","shaadi","kab","kar","rahe","ho"], "labels": ["URD","URD","URD","URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "I can't focus aaj kaam mein bilkul dil nahi lag raha", "words": ["I","can't","focus","aaj","kaam","mein","bilkul","dil","nahi","lag","raha"], "labels": ["ENG","ENG","ENG","URD","URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Yaar office mein aajkal bohot politics chal rahi hai", "words": ["Yaar","office","mein","aajkal","bohot","politics","chal","rahi","hai"], "labels": ["URD","ENG","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Mujhe pata tha ke tum late aao gay hamesha ki tarah", "words": ["Mujhe","pata","tha","ke","tum","late","aao","gay","hamesha","ki","tarah"], "labels": ["URD","URD","URD","URD","URD","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Bas ab bohot ho gaya I need a proper vacation", "words": ["Bas","ab","bohot","ho","gaya","I","need","a","proper","vacation"], "labels": ["URD","URD","URD","URD","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Ye discount sirf online available hai stores mein nahi", "words": ["Ye","discount","sirf","online","available","hai","stores","mein","nahi"], "labels": ["URD","ENG","URD","ENG","ENG","URD","ENG","URD","URD"]},
    {"sentence": "Mera pura weekend assignments mein hi guzar gaya", "words": ["Mera","pura","weekend","assignments","mein","hi","guzar","gaya"], "labels": ["URD","URD","ENG","ENG","URD","URD","URD","URD"]},
    {"sentence": "Yaar tumhe pata bhi hai kitna important ye meeting hai", "words": ["Yaar","tumhe","pata","bhi","hai","kitna","important","ye","meeting","hai"], "labels": ["URD","URD","URD","URD","URD","URD","ENG","URD","ENG","URD"]},
    {"sentence": "Bijli chali gayi thi so I couldn't finish the report", "words": ["Bijli","chali","gayi","thi","so","I","couldn't","finish","the","report"], "labels": ["URD","URD","URD","URD","ENG","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Ye kaam mujhse nahi hoga honestly speaking", "words": ["Ye","kaam","mujhse","nahi","hoga","honestly","speaking"], "labels": ["URD","URD","URD","URD","URD","ENG","ENG"]},
    {"sentence": "Uski shaadi mein hum sab ne khoob enjoy kiya", "words": ["Uski","shaadi","mein","hum","sab","ne","khoob","enjoy","kiya"], "labels": ["URD","URD","URD","URD","URD","URD","URD","ENG","URD"]},
    {"sentence": "I told you already ye plan kaam nahi karega", "words": ["I","told","you","already","ye","plan","kaam","nahi","karega"], "labels": ["ENG","ENG","ENG","ENG","URD","ENG","URD","URD","URD"]},
    {"sentence": "Kal ki flight delay ho gayi thi kaafi ghanton ke liye", "words": ["Kal","ki","flight","delay","ho","gayi","thi","kaafi","ghanton","ke","liye"], "labels": ["URD","URD","ENG","ENG","URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Aap ka order confirm ho gaya hai thank you", "words": ["Aap","ka","order","confirm","ho","gaya","hai","thank","you"], "labels": ["URD","URD","ENG","ENG","URD","URD","URD","ENG","ENG"]},
    {"sentence": "Bhai kya scene hai aaj kal tum dikhte hi nahi", "words": ["Bhai","kya","scene","hai","aaj","kal","tum","dikhte","hi","nahi"], "labels": ["URD","URD","ENG","URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Mera confidence thora low hai aaj kal honestly", "words": ["Mera","confidence","thora","low","hai","aaj","kal","honestly"], "labels": ["URD","ENG","URD","ENG","URD","URD","URD","ENG"]},
    {"sentence": "I just want peace of mind bas aur kuch nahi chahiye", "words": ["I","just","want","peace","of","mind","bas","aur","kuch","nahi","chahiye"], "labels": ["ENG","ENG","ENG","ENG","ENG","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Uska behavior mujhe bilkul acha nahi laga aaj", "words": ["Uska","behavior","mujhe","bilkul","acha","nahi","laga","aaj"], "labels": ["URD","ENG","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Kal se sab kuch normal ho jayega hopefully", "words": ["Kal","se","sab","kuch","normal","ho","jayega","hopefully"], "labels": ["URD","URD","URD","URD","ENG","URD","URD","ENG"]},
    {"sentence": "Mujhe bilkul yaad nahi ke maine kya kaha tha", "words": ["Mujhe","bilkul","yaad","nahi","ke","maine","kya","kaha","tha"], "labels": ["URD","URD","URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "This semester bohot heavy hai courses ki wajah se", "words": ["This","semester","bohot","heavy","hai","courses","ki","wajah","se"], "labels": ["ENG","ENG","URD","ENG","URD","ENG","URD","URD","URD"]},
    {"sentence": "Aaj mera mood nahi hai for anything", "words": ["Aaj","mera","mood","nahi","hai","for","anything"], "labels": ["URD","URD","ENG","URD","URD","ENG","ENG"]},
    {"sentence": "Chalo abhi nikalte hain warna traffic mein phas jayenge", "words": ["Chalo","abhi","nikalte","hain","warna","traffic","mein","phas","jayenge"], "labels": ["URD","URD","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Ye job bohot demanding hai but I love the work", "words": ["Ye","job","bohot","demanding","hai","but","I","love","the","work"], "labels": ["URD","ENG","URD","ENG","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Mujhe ye samajh nahi aata ke log itna judgmental kyun hote hain", "words": ["Mujhe","ye","samajh","nahi","aata","ke","log","itna","judgmental","kyun","hote","hain"], "labels": ["URD","URD","URD","URD","URD","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Kal party mein bohot fun aaya sab log the wahan", "words": ["Kal","party","mein","bohot","fun","aaya","sab","log","the","wahan"], "labels": ["URD","ENG","URD","URD","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "I can't deal with this stress anymore honestly", "words": ["I","can't","deal","with","this","stress","anymore","honestly"], "labels": ["ENG","ENG","ENG","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Mujhe abhi bhi wo din yaad hai jab hum mile the", "words": ["Mujhe","abhi","bhi","wo","din","yaad","hai","jab","hum","mile","the"], "labels": ["URD","URD","URD","URD","URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Yaar naya semester start ho gaya excited feel nahi ho raha", "words": ["Yaar","naya","semester","start","ho","gaya","excited","feel","nahi","ho","raha"], "labels": ["URD","URD","ENG","ENG","URD","URD","ENG","ENG","URD","URD","URD"]},
    {"sentence": "Kal ka episode dekha kya bohot dramatic tha", "words": ["Kal","ka","episode","dekha","kya","bohot","dramatic","tha"], "labels": ["URD","URD","ENG","URD","URD","URD","ENG","URD"]},
    {"sentence": "Bhai relax karo sab kuch theek ho jayega eventually", "words": ["Bhai","relax","karo","sab","kuch","theek","ho","jayega","eventually"], "labels": ["URD","ENG","URD","URD","URD","URD","URD","URD","ENG"]},
    {"sentence": "Mujhe office se early nikalna hai kal doctor ke pass jana hai", "words": ["Mujhe","office","se","early","nikalna","hai","kal","doctor","ke","pass","jana","hai"], "labels": ["URD","ENG","URD","ENG","URD","URD","URD","ENG","URD","URD","URD","URD"]},
    {"sentence": "This coffee bohot strong hai but I needed it today", "words": ["This","coffee","bohot","strong","hai","but","I","needed","it","today"], "labels": ["ENG","ENG","URD","ENG","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Kal se routine follow karna zaroori hai warna sab bigar jayega", "words": ["Kal","se","routine","follow","karna","zaroori","hai","warna","sab","bigar","jayega"], "labels": ["URD","URD","ENG","ENG","URD","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Bhai mujhe ye whole situation bohot confusing lag rahi hai", "words": ["Bhai","mujhe","ye","whole","situation","bohot","confusing","lag","rahi","hai"], "labels": ["URD","URD","URD","ENG","ENG","URD","ENG","URD","URD","URD"]},
    {"sentence": "Aaj ka lecture bohot boring tha honestly I almost slept", "words": ["Aaj","ka","lecture","bohot","boring","tha","honestly","I","almost","slept"], "labels": ["URD","URD","ENG","URD","ENG","URD","ENG","ENG","ENG","ENG"]},
    {"sentence": "Yaar mujhe abhi thori der akela chorho please", "words": ["Yaar","mujhe","abhi","thori","der","akela","chorho","please"], "labels": ["URD","URD","URD","URD","URD","URD","URD","ENG"]},
    {"sentence": "Mera internet phir se down ho gaya kaam rukk gaya", "words": ["Mera","internet","phir","se","down","ho","gaya","kaam","rukk","gaya"], "labels": ["URD","MIX","URD","URD","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "I genuinely think humein break lena chahiye is hafte", "words": ["I","genuinely","think","humein","break","lena","chahiye","is","hafte"], "labels": ["ENG","ENG","ENG","URD","ENG","URD","URD","URD","URD"]},
    {"sentence": "Kal shaam ko free ho tum kahin chalein kya", "words": ["Kal","shaam","ko","free","ho","tum","kahin","chalein","kya"], "labels": ["URD","URD","URD","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Mujhe abhi realize hua ke maine file save hi nahi ki", "words": ["Mujhe","abhi","realize","hua","ke","maine","file","save","hi","nahi","ki"], "labels": ["URD","URD","ENG","URD","URD","URD","ENG","ENG","URD","URD","URD"]},
    {"sentence": "Bhai project deadline extend ho gayi thank god", "words": ["Bhai","project","deadline","extend","ho","gayi","thank","god"], "labels": ["URD","ENG","ENG","ENG","URD","URD","ENG","ENG"]},
    {"sentence": "Yaar itni saari notifications aa rahi hain phone band kar deta hoon", "words": ["Yaar","itni","saari","notifications","aa","rahi","hain","phone","band","kar","deta","hoon"], "labels": ["URD","URD","URD","ENG","URD","URD","URD","MIX","URD","URD","URD","URD"]},
    {"sentence": "Mummy ne dopher ko biryani banai thi bohot tasty thi", "words": ["Mummy","ne","dopher","ko","biryani","banai","thi","bohot","tasty","thi"], "labels": ["URD","URD","URD","URD","URD","URD","URD","URD","ENG","URD"]},
    {"sentence": "I am not in the mood for a debate abhi", "words": ["I","am","not","in","the","mood","for","a","debate","abhi"], "labels": ["ENG","ENG","ENG","ENG","ENG","ENG","ENG","ENG","ENG","URD"]},
    {"sentence": "Kal raat ko bijli bar bar ja rahi thi so annoying", "words": ["Kal","raat","ko","bijli","bar","bar","ja","rahi","thi","so","annoying"], "labels": ["URD","URD","URD","URD","URD","URD","URD","URD","URD","ENG","ENG"]},
    {"sentence": "Bhai tumhara plan kaafi solid lag raha hai actually", "words": ["Bhai","tumhara","plan","kaafi","solid","lag","raha","hai","actually"], "labels": ["URD","URD","ENG","URD","ENG","URD","URD","URD","ENG"]},
    {"sentence": "Mujhe office ka environment aajkal bilkul acha nahi lag raha", "words": ["Mujhe","office","ka","environment","aajkal","bilkul","acha","nahi","lag","raha"], "labels": ["URD","ENG","URD","ENG","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Aaj ka schedule kaafi packed hai back to back classes", "words": ["Aaj","ka","schedule","kaafi","packed","hai","back","to","back","classes"], "labels": ["URD","URD","ENG","URD","ENG","URD","ENG","ENG","ENG","ENG"]},
    {"sentence": "Bhai mujhe pata hai kaam pending hai but I am too tired", "words": ["Bhai","mujhe","pata","hai","kaam","pending","hai","but","I","am","too","tired"], "labels": ["URD","URD","URD","URD","URD","ENG","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Sara ghar saaf kar diya finally feels so good now", "words": ["Sara","ghar","saaf","kar","diya","finally","feels","so","good","now"], "labels": ["URD","URD","URD","URD","URD","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Mujhe wo restaurant ka khana bilkul pasand nahi aya", "words": ["Mujhe","wo","restaurant","ka","khana","bilkul","pasand","nahi","aya"], "labels": ["URD","URD","ENG","URD","URD","URD","URD","URD","URD"]},
    {"sentence": "Bhai signal hi nahi aa raha call drop ho gayi", "words": ["Bhai","signal","hi","nahi","aa","raha","call","drop","ho","gayi"], "labels": ["URD","ENG","URD","URD","URD","URD","ENG","ENG","URD","URD"]},
    {"sentence": "Kal ka function bohot achi tarah organize hua tha", "words": ["Kal","ka","function","bohot","achi","tarah","organize","hua","tha"], "labels": ["URD","URD","ENG","URD","URD","URD","ENG","URD","URD"]},
    {"sentence": "I just need a proper nap mujhe neend aa rahi hai", "words": ["I","just","need","a","proper","nap","mujhe","neend","aa","rahi","hai"], "labels": ["ENG","ENG","ENG","ENG","ENG","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Bhai class time pe start hui thi you missed the intro", "words": ["Bhai","class","time","pe","start","hui","thi","you","missed","the","intro"], "labels": ["URD","ENG","ENG","URD","ENG","URD","URD","ENG","ENG","ENG","ENG"]},
    {"sentence": "Mujhe aaj bohot achi news mili I got the internship", "words": ["Mujhe","aaj","bohot","achi","news","mili","I","got","the","internship"], "labels": ["URD","URD","URD","URD","ENG","URD","ENG","ENG","ENG","ENG"]},
    {"sentence": "Yaar tumhara mood aaj kuch off lag raha hai kya hua", "words": ["Yaar","tumhara","mood","aaj","kuch","off","lag","raha","hai","kya","hua"], "labels": ["URD","URD","ENG","URD","URD","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Mujhe results ka bohot tension ho raha hai abhi se", "words": ["Mujhe","results","ka","bohot","tension","ho","raha","hai","abhi","se"], "labels": ["URD","ENG","URD","URD","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Bhai kal ki flight miss ho gayi thi major delay ki wajah se", "words": ["Bhai","kal","ki","flight","miss","ho","gayi","thi","major","delay","ki","wajah","se"], "labels": ["URD","URD","URD","ENG","ENG","URD","URD","URD","ENG","ENG","URD","URD","URD"]},
    {"sentence": "I feel so lazy today kuch bhi karne ka dil nahi kar raha", "words": ["I","feel","so","lazy","today","kuch","bhi","karne","ka","dil","nahi","kar","raha"], "labels": ["ENG","ENG","ENG","ENG","ENG","URD","URD","URD","URD","URD","URD","URD","URD"]},
]

extra = [
    {"sentence": "Bhai aaj ka weather bilkul perfect hai for a drive", "words": ["Bhai","aaj","ka","weather","bilkul","perfect","hai","for","a","drive"], "labels": ["URD","URD","URD","ENG","URD","ENG","URD","ENG","ENG","ENG"]},
    {"sentence": "Mujhe abhi bhi wo purani baatein yaad aati hain sometimes", "words": ["Mujhe","abhi","bhi","wo","purani","baatein","yaad","aati","hain","sometimes"], "labels": ["URD","URD","URD","URD","URD","URD","URD","URD","URD","ENG"]},
    {"sentence": "Kal se sab kuch sort out ho jayega hopefully yaar", "words": ["Kal","se","sab","kuch","sort","out","ho","jayega","hopefully","yaar"], "labels": ["URD","URD","URD","URD","ENG","ENG","URD","URD","ENG","URD"]},
    {"sentence": "I really needed this vacation itna thak gaya tha main", "words": ["I","really","needed","this","vacation","itna","thak","gaya","tha","main"], "labels": ["ENG","ENG","ENG","ENG","ENG","URD","URD","URD","URD","URD"]},
    {"sentence": "Bhai tumhe kal ki party ki details mili kya", "words": ["Bhai","tumhe","kal","ki","party","ki","details","mili","kya"], "labels": ["URD","URD","URD","URD","ENG","URD","ENG","URD","URD"]},
    {"sentence": "Mera mind abhi bilkul kaam nahi kar raha exam ki wajah se", "words": ["Mera","mind","abhi","bilkul","kaam","nahi","kar","raha","exam","ki","wajah","se"], "labels": ["URD","ENG","URD","URD","URD","URD","URD","URD","ENG","URD","URD","URD"]},
    {"sentence": "Yaar mujhe lagta hai we should just cancel the trip", "words": ["Yaar","mujhe","lagta","hai","we","should","just","cancel","the","trip"], "labels": ["URD","URD","URD","URD","ENG","ENG","ENG","ENG","ENG","ENG"]},
    {"sentence": "Kal subah jaldi utho hum log trekking pe jayenge", "words": ["Kal","subah","jaldi","utho","hum","log","trekking","pe","jayenge"], "labels": ["URD","URD","URD","URD","URD","URD","ENG","URD","URD"]},
    {"sentence": "Bhai maine socha nahi tha ke tum itna support karo gay", "words": ["Bhai","maine","socha","nahi","tha","ke","tum","itna","support","karo","gay"], "labels": ["URD","URD","URD","URD","URD","URD","URD","URD","ENG","URD","URD"]},
    {"sentence": "This traffic jam khatam hi nahi ho raha aaj tou", "words": ["This","traffic","jam","khatam","hi","nahi","ho","raha","aaj","tou"], "labels": ["ENG","ENG","ENG","URD","URD","URD","URD","URD","URD","URD"]},
]
data.extend(extra)

print(f"Base sentences: {len(data)}")

rows = []
for entry in data:
    assert len(entry["words"]) == len(entry["labels"]), entry["sentence"]
    for word, label in zip(entry["words"], entry["labels"]):
        rows.append({
            "sentence": entry["sentence"],
            "word": word,
            "label": label
        })

df = pd.DataFrame(rows)
df.to_csv("dataset.csv", index=False, encoding="utf-8")

print(f"Dataset created: {len(df)} word entries")
print(f"Sentences: {df.sentence.nunique()}")
print("Label distribution:")
print(df.label.value_counts())
# Out:
# Base sentences: 155
# Dataset created: 1419 word entries
# Sentences: 155
# Label distribution:
# label
# URD    925
# ENG    486
# MIX      8
# Name: count, dtype: int64

# %% [markdown]
# ## Cell 2 — Inspect the dataset

# %%
df.head(20)
# Out:
#                                              sentence          word label
# 0                           Aaj ka din bohot busy tha           Aaj   URD
# 1                           Aaj ka din bohot busy tha            ka   URD
# 2                           Aaj ka din bohot busy tha           din   URD
# 3                           Aaj ka din bohot busy tha         bohot   URD
# 4                           Aaj ka din bohot busy tha          busy   ENG
# 5                           Aaj ka din bohot busy tha           tha   URD
# 6             Yaar seriously I can not even right now          Yaar   URD
# 7             Yaar seriously I can not even right now     seriously   ENG
# 8             Yaar seriously I can not even right now             I   ENG
# 9             Yaar seriously I can not even right now           can   ENG
# 10            Yaar seriously I can not even right now           not   ENG
# 11            Yaar seriously I can not even right now          even   ENG
# ...

# %%
df.label.value_counts().plot(kind="bar", title="Label distribution")
# Out:
# <Axes: title={'center': 'Label distribution'}, xlabel='label'>

# %% [markdown]
# ## Cell 3 — Save / download the CSV for HuggingFace upload

# %%
from google.colab import files
files.download("dataset.csv")
